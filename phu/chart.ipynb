# %%
import matplotlib.pyplot as plt

# %%
train_accuracy = [
    0.4646,
    0.8828,
    0.9609,
    0.9774,
    0.9853,
    0.9901,
    0.9923,
    0.9940,
    0.9949,
    0.9958,
]
test_accuracy = [
    0.2023,
    0.1863,
    0.1814,
    0.2001,
    0.2125,
    0.2144,
    0.2150,
    0.2151,
    0.2175,
    0.2171,
]
plt.plot(train_accuracy, '-x', label='Train')
plt.plot(test_accuracy, '-x', label='Test')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('MnasNet Accuracy')
plt.legend()

# %%
train_loss = [
    3.9068,
    1.3349,
    0.4419,
    0.2435,
    0.1714,
    0.1378,
    0.1172,
    0.1035,
    0.0927,
    0.0849,
]
test_loss = [
    3.8339,
    3.4394,
    3.5385,
    3.5300,
    3.5473,
    3.5850,
    3.6081,
    3.6518,
    3.6572,
    3.6666,
]
plt.plot(train_loss, '-x', label='Train')
plt.plot(test_loss, '-x', label='Test')
plt.xlabel('Epochs')
plt.ylabel('CE Loss')
plt.title('MnasNet Loss')
plt.legend()

# %%
train_accuracy = [
    0.2325,
    0.6590,
    0.8189,
    0.9226,
    0.9573,
    0.9741,
    0.9846,
    0.9885,
    0.9909,
    0.9931,
    0.9938,
    0.9949,
    0.9957,
    0.9961,
    0.9967,
    0.9970,
    0.9974,
    0.9976,
]
test_accuracy = [
    0.2115,
    0.5004,
    0.8594,
    0.8935,
    0.9106,
    0.9252,
    0.9378,
    0.9407,
    0.9452,
    0.9459,
    0.9494,
    0.9497,
    0.9520,
    0.9539,
    0.9541,
    0.9557,
    0.9565,
    0.9566,
]
plt.plot(train_accuracy, '-x', label='Train')
plt.plot(test_accuracy, '-x', label='Test')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('ShuffleNet Accuracy')
plt.legend()

# %%
train_loss = [
    3.9779,
    2.2169,
    0.9817,
    0.3836,
    0.1949,
    0.1229,
    0.0878,
    0.0707,
    0.0618,
    0.0551,
    0.0504,
    0.0464,
    0.0432,
    0.0402,
    0.0381,
    0.0359,
    0.0341,
    0.0327,
]
test_loss = [
    4.4923,
    2.6408,
    0.6122,
    0.5015,
    0.3796,
    0.3023,
    0.2559,
    0.2414,
    0.2240,
    0.2139,
    0.2080,
    0.1988,
    0.1914,
    0.1869,
    0.1814,
    0.1778,
    0.1732,
    0.1726,
]
plt.plot(train_loss, '-x', label='Train')
plt.plot(test_loss, '-x', label='Test')
plt.xlabel('Epochs')
plt.ylabel('CE Loss')
plt.title('ShuffleNet Loss')
plt.legend()

# %%
train_accuracy = [
    0.2707,
    0.7150,
    0.8726,
    0.9368,
    0.9677,
    0.9816,
    0.9874,
    0.9897,
    0.9917,
    0.9932,
    0.9945,
    0.9951,
    0.9960,
    0.9962,
    0.9969,
    0.9968,
    0.9974,
    0.9976,
    0.9978,
    0.9979,
]
test_accuracy = [
    0.0472,
    0.0384,
    0.0541,
    0.0584,
    0.0936,
    0.1255,
    0.1579,
    0.1907,
    0.2325,
    0.2813,
    0.3211,
    0.3804,
    0.4645,
    0.5357,
    0.6066,
    0.6890,
    0.7470,
    0.8065,
    0.8362,
    0.8612,
]
plt.plot(train_accuracy, '-x', label='Train')
plt.plot(test_accuracy, '-x', label='Test')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('MobileNet Accuracy')
plt.legend()

# %%
train_loss = [
    3.1514,
    1.1037,
    0.4189,
    0.2031,
    0.1133,
    0.0727,
    0.0553,
    0.0438,
    0.0367,
    0.0316,
    0.0274,
    0.0246,
    0.0221,
    0.0205,
    0.0185,
    0.0179,
    0.0160,
    0.0153,
    0.0148,
    0.0144,
]
test_loss = [
    5.1388,
    7.8430,
    8.6473,
    8.0413,
    7.4969,
    6.9662,
    5.9936,
    5.1189,
    4.5245,
    4.2200,
    3.8575,
    3.2728,
    2.5882,
    2.0944,
    1.6424,
    1.2102,
    0.9686,
    0.7581,
    0.6456,
    0.5599,
]
plt.plot(train_loss, '-x', label='Train')
plt.plot(test_loss, '-x', label='Test')
plt.xlabel('Epochs')
plt.ylabel('CE Loss')
plt.title('MobileNet Loss')
plt.legend()

# %%
train_accuracy = [
    0.0664,
    0.1733,
    0.2396,
    0.2490,
    0.2600,
    0.2595,
    0.2559,
    0.2527,
    0.2500,
    0.2466,
    0.2470,
    0.2388,
    0.2403,
    0.2363,
    0.2348,
    0.2303,
    0.2315,
    0.2287,
    0.2277,
    0.2273,
    0.2246,
]
test_accuracy = [
    0.1772,
    0.1689,
    0.2098,
    0.2380,
    0.2316,
    0.2251,
    0.2171,
    0.2150,
    0.2097,
    0.2074,2542856
    0.2028,
    0.1984,
    0.1983,
    0.1952,
    0.1922,
    0.1894,
    0.1878,
    0.1867,
    0.1856,
    0.1847,
    0.1845,
]
plt.plot(train_accuracy, '-x', label='Train')
plt.plot(test_accuracy, '-x', label='Test')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('SqueezeNet Accuracy')
plt.legend()

# %%
train_loss = [
    431.2005,
    148.9209,
    63.0098,
    39.1265,
    29.5549,
    24.2724,
    21.0922,
    18.7492,
    17.0069,
    15.6178,
    14.3651,
    13.4179,
    12.4220,
    11.6755,
    11.0308,
    10.4309,
    9.9063,
    9.4121,
    9.0940,
    8.8992,
    8.7999,
]
test_loss = [
    167.2106,
    48.5372,
    19.9869,
    11.1337,
    8.4543,
    6.9459,
    6.0939,
    5.6554,
    5.3223,
    5.0393,
    4.8408,
    4.6847,
    4.5599,
    4.4528,
    4.3749,
    4.3072,
    4.2434,
    4.1944,
    4.1708,
    4.1508,
    4.1415,
]
plt.plot(train_loss, '-x', label='Train')
plt.plot(test_loss, '-x', label='Test')
plt.xlabel('Epochs')
plt.ylabel('CE Loss')
plt.title('SqueezeNet Loss')
plt.legend()
